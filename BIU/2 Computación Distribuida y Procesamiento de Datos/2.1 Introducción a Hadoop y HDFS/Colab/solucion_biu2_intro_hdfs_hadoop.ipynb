# %% [markdown]
# # Instalación de Hadoop

# %% [markdown]
#  bajar la distribución

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.4.1/hadoop-3.4.1.tar.gz
# Out:
# --2024-11-12 19:14:30--  https://downloads.apache.org/hadoop/common/hadoop-3.4.1/hadoop-3.4.1.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.208.237, 2a01:4f8:10a:39da::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 974002355 (929M) [application/x-gzip]
# Saving to: ‘hadoop-3.4.1.tar.gz’
#
# hadoop-3.4.1.tar.gz 100%[===================>] 928.88M  18.5MB/s    in 52s
#
# 2024-11-12 19:15:23 (17.8 MB/s) - ‘hadoop-3.4.1.tar.gz’ saved [974002355/974002355]

# %% [markdown]
# * extraerla en el sistema de archivos de colab

# %%
# !tar -xzf hadoop-3.4.1.tar.gz

# %% [markdown]
# * mover la distribución de hadoop  /usr/local

# %%
# !mv  hadoop-3.4.1/ /usr/local/

# %% [markdown]
# ## Configuración

# %% [markdown]
# * actualizamos variables de entorno (JAVA_HOME, PATH)

# %%
import os
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["PATH"] = os.environ["PATH"] + ":" + "/usr/local/hadoop-3.4.1/bin"

# %% [markdown]
# * comprobamos instalación

# %%
# !hadoop version
# Out:
# Hadoop 3.4.1
# Source code repository https://github.com/apache/hadoop.git -r 4d7825309348956336b8f06a08322b78422849b1
# Compiled by mthakur on 2024-10-09T14:57Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.23.4
# From source with checksum 7292fe9dba5e2e44e3a9f763fce3e680
# This command was run using /usr/local/hadoop-3.4.1/share/hadoop/common/hadoop-common-3.4.1.jar

# %% [markdown]
# ## Ejecución de ejemplos

# %% [markdown]
# Una de las formas tradicionales de asegurarnos que un ambiente de Hadoop recién instalado funciona correctamente, es ejecutando el *jar* de ejemplos *map-reduce* incluido con toda instalación de hadoop (*hadoop-mapreduce-examples.jar*).
#
# [Hadoop Map Reduce Examples](http://svn.apache.org/viewvc/hadoop/common/trunk/hadoop-mapreduce-project/hadoop-mapreduce-examples/src/main/java/org/apache/hadoop/examples/)

# %% [markdown]
# 1. Creamos un directorio de ficheros en los que volquemos los xml de hadoop

# %%
# %%bash
# mkdir ~/input
# cp /usr/local/hadoop-3.4.1/etc/hadoop/*.xml ~/input
# ls ~/input
# Out:
# capacity-scheduler.xml
# core-site.xml
# hadoop-policy.xml
# hdfs-rbf-site.xml
# hdfs-site.xml
# httpfs-site.xml
# kms-acls.xml
# kms-site.xml
# mapred-site.xml
# yarn-site.xml

# %% [markdown]
# 2. Ejecutamos hadoop jar con el fin de ejecutar uno de los ejemplos por defecto, en este caso el grep que busca expresiones regulares dentro de los ficheros que le especifiquemos.

# %%
# %%bash
# hadoop jar \
#   /usr/local/hadoop-3.4.1/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.4.1.jar \
#   grep ~/input ~/grep_example 'allowed[.]*'
# Out:
# 2024-11-12 19:22:19,186 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-11-12 19:22:19,821 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-11-12 19:22:19,823 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-11-12 19:22:20,769 INFO input.FileInputFormat: Total input files to process : 10
# 2024-11-12 19:22:20,940 INFO mapreduce.JobSubmitter: number of splits:10
# 2024-11-12 19:22:22,615 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local928394036_0001
# 2024-11-12 19:22:22,621 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-11-12 19:22:24,040 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2024-11-12 19:22:24,041 INFO mapreduce.Job: Running job: job_local928394036_0001
# 2024-11-12 19:22:24,081 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2024-11-12 19:22:24,110 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:24,112 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:24,112 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:24,126 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2024-11-12 19:22:24,378 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2024-11-12 19:22:24,379 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000000_0
# 2024-11-12 19:22:24,436 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:24,440 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:24,440 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:24,487 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:24,497 INFO mapred.MapTask: Processing split: file:/root/input/hadoop-policy.xml:0+14007
# 2024-11-12 19:22:24,738 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:24,738 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:24,738 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:24,739 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:24,739 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:24,745 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:24,781 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:24,782 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:24,782 INFO mapred.MapTask: Spilling map output
# 2024-11-12 19:22:24,782 INFO mapred.MapTask: bufstart = 0; bufend = 459; bufvoid = 104857600
# 2024-11-12 19:22:24,782 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214292(104857168); length = 105/6553600
# 2024-11-12 19:22:24,808 INFO mapred.MapTask: Finished spill 0
# 2024-11-12 19:22:24,832 INFO mapred.Task: Task:attempt_local928394036_0001_m_000000_0 is done. And is in the process of committing
# 2024-11-12 19:22:24,837 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:24,837 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000000_0' done.
# 2024-11-12 19:22:24,848 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=296800
# 		FILE: Number of bytes written=994815
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=325
# 		Map output records=27
# 		Map output bytes=459
# 		Map output materialized bytes=25
# 		Input split bytes=99
# 		Combine input records=27
# 		Combine output records=1
# 		Spilled Records=1
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=357564416
# 	File Input Format Counters
# 		Bytes Read=14007
# 2024-11-12 19:22:24,848 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000000_0
# 2024-11-12 19:22:24,849 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000001_0
# 2024-11-12 19:22:24,851 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:24,851 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:24,851 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:24,852 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:24,854 INFO mapred.MapTask: Processing split: file:/root/input/capacity-scheduler.xml:0+9213
# 2024-11-12 19:22:24,906 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:24,906 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:24,907 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:24,907 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:24,907 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:24,908 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:24,921 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:24,929 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:24,929 INFO mapred.MapTask: Spilling map output
# 2024-11-12 19:22:24,929 INFO mapred.MapTask: bufstart = 0; bufend = 16; bufvoid = 104857600
# 2024-11-12 19:22:24,929 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214396(104857584); length = 1/6553600
# 2024-11-12 19:22:24,931 INFO mapred.MapTask: Finished spill 0
# 2024-11-12 19:22:24,938 INFO mapred.Task: Task:attempt_local928394036_0001_m_000001_0 is done. And is in the process of committing
# 2024-11-12 19:22:24,943 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:24,943 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000001_0' done.
# 2024-11-12 19:22:24,944 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=307005
# 		FILE: Number of bytes written=994871
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=244
# 		Map output records=1
# 		Map output bytes=16
# 		Map output materialized bytes=24
# 		Input split bytes=104
# 		Combine input records=1
# 		Combine output records=1
# 		Spilled Records=1
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=22
# 		Total committed heap usage (bytes)=357564416
# 	File Input Format Counters
# 		Bytes Read=9213
# 2024-11-12 19:22:24,944 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000001_0
# 2024-11-12 19:22:24,944 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000002_0
# 2024-11-12 19:22:24,957 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:24,958 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:24,958 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:24,958 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:24,964 INFO mapred.MapTask: Processing split: file:/root/input/kms-acls.xml:0+3518
# 2024-11-12 19:22:25,116 INFO mapreduce.Job: Job job_local928394036_0001 running in uber mode : false
# 2024-11-12 19:22:25,119 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,125 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,125 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,125 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,125 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,127 INFO mapreduce.Job:  map 100% reduce 0%
# 2024-11-12 19:22:25,142 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,147 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,148 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,153 INFO mapred.Task: Task:attempt_local928394036_0001_m_000002_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,159 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,159 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000002_0' done.
# 2024-11-12 19:22:25,160 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000002_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=311515
# 		FILE: Number of bytes written=994909
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=135
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=94
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=357564416
# 	File Input Format Counters
# 		Bytes Read=3518
# 2024-11-12 19:22:25,160 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000002_0
# 2024-11-12 19:22:25,161 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000003_0
# 2024-11-12 19:22:25,165 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,165 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,165 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,166 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,171 INFO mapred.MapTask: Processing split: file:/root/input/hdfs-site.xml:0+775
# 2024-11-12 19:22:25,204 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,204 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,204 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,204 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,204 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,209 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,223 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,225 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,238 INFO mapred.Task: Task:attempt_local928394036_0001_m_000003_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,240 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,240 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000003_0' done.
# 2024-11-12 19:22:25,241 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000003_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=313282
# 		FILE: Number of bytes written=994947
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=21
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=95
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=15
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=775
# 2024-11-12 19:22:25,241 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000003_0
# 2024-11-12 19:22:25,241 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000004_0
# 2024-11-12 19:22:25,242 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,242 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,242 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,243 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,248 INFO mapred.MapTask: Processing split: file:/root/input/core-site.xml:0+774
# 2024-11-12 19:22:25,265 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,265 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,265 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,265 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,265 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,268 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,274 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,275 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,286 INFO mapred.Task: Task:attempt_local928394036_0001_m_000004_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,288 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,288 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000004_0' done.
# 2024-11-12 19:22:25,289 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000004_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=315048
# 		FILE: Number of bytes written=994985
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=95
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=774
# 2024-11-12 19:22:25,289 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000004_0
# 2024-11-12 19:22:25,289 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000005_0
# 2024-11-12 19:22:25,290 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,290 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,291 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,291 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,294 INFO mapred.MapTask: Processing split: file:/root/input/mapred-site.xml:0+758
# 2024-11-12 19:22:25,318 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,319 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,319 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,319 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,319 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,320 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,336 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,337 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,344 INFO mapred.Task: Task:attempt_local928394036_0001_m_000005_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,356 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,356 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000005_0' done.
# 2024-11-12 19:22:25,360 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000005_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=316798
# 		FILE: Number of bytes written=995023
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=21
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=97
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=3
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=758
# 2024-11-12 19:22:25,360 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000005_0
# 2024-11-12 19:22:25,360 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000006_0
# 2024-11-12 19:22:25,362 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,362 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,362 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,362 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,366 INFO mapred.MapTask: Processing split: file:/root/input/yarn-site.xml:0+690
# 2024-11-12 19:22:25,386 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,386 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,386 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,386 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,386 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,389 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,393 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,394 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,403 INFO mapred.Task: Task:attempt_local928394036_0001_m_000006_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,406 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,406 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000006_0' done.
# 2024-11-12 19:22:25,407 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000006_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=317968
# 		FILE: Number of bytes written=995061
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=19
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=95
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=690
# 2024-11-12 19:22:25,407 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000006_0
# 2024-11-12 19:22:25,407 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000007_0
# 2024-11-12 19:22:25,409 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,409 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,409 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,409 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,412 INFO mapred.MapTask: Processing split: file:/root/input/hdfs-rbf-site.xml:0+683
# 2024-11-12 19:22:25,437 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,437 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,437 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,437 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,437 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,438 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,443 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,444 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,448 INFO mapred.Task: Task:attempt_local928394036_0001_m_000007_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,451 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,451 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000007_0' done.
# 2024-11-12 19:22:25,452 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000007_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=319131
# 		FILE: Number of bytes written=995099
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=99
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=683
# 2024-11-12 19:22:25,452 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000007_0
# 2024-11-12 19:22:25,453 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000008_0
# 2024-11-12 19:22:25,461 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,462 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,462 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,462 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,464 INFO mapred.MapTask: Processing split: file:/root/input/kms-site.xml:0+682
# 2024-11-12 19:22:25,493 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,493 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,493 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,493 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,493 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,501 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,507 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,507 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,513 INFO mapred.Task: Task:attempt_local928394036_0001_m_000008_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,516 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,516 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000008_0' done.
# 2024-11-12 19:22:25,517 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000008_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=320293
# 		FILE: Number of bytes written=995137
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=94
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=682
# 2024-11-12 19:22:25,517 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000008_0
# 2024-11-12 19:22:25,517 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_m_000009_0
# 2024-11-12 19:22:25,520 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,520 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,520 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,521 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,527 INFO mapred.MapTask: Processing split: file:/root/input/httpfs-site.xml:0+620
# 2024-11-12 19:22:25,555 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:25,555 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:25,555 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:25,555 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:25,555 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:25,562 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:25,567 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:25,568 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:25,598 INFO mapred.Task: Task:attempt_local928394036_0001_m_000009_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,602 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:25,602 INFO mapred.Task: Task 'attempt_local928394036_0001_m_000009_0' done.
# 2024-11-12 19:22:25,603 INFO mapred.Task: Final Counters for attempt_local928394036_0001_m_000009_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=321393
# 		FILE: Number of bytes written=995175
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=17
# 		Map output records=0
# 		Map output bytes=0
# 		Map output materialized bytes=6
# 		Input split bytes=97
# 		Combine input records=0
# 		Combine output records=0
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=620
# 2024-11-12 19:22:25,603 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_m_000009_0
# 2024-11-12 19:22:25,603 INFO mapred.LocalJobRunner: map task executor complete.
# 2024-11-12 19:22:25,608 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2024-11-12 19:22:25,608 INFO mapred.LocalJobRunner: Starting task: attempt_local928394036_0001_r_000000_0
# 2024-11-12 19:22:25,620 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:25,620 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:25,620 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:25,620 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:25,624 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@6c10c988
# 2024-11-12 19:22:25,626 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-11-12 19:22:25,655 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2024-11-12 19:22:25,658 INFO reduce.EventFetcher: attempt_local928394036_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2024-11-12 19:22:25,716 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000009_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,722 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000009_0
# 2024-11-12 19:22:25,724 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->2
# 2024-11-12 19:22:25,732 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000006_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,733 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000006_0
# 2024-11-12 19:22:25,734 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 2, commitMemory -> 2, usedMemory ->4
# 2024-11-12 19:22:25,736 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000005_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,743 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000005_0
# 2024-11-12 19:22:25,743 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 3, commitMemory -> 4, usedMemory ->6
# 2024-11-12 19:22:25,745 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000002_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,748 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000002_0
# 2024-11-12 19:22:25,749 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 4, commitMemory -> 6, usedMemory ->8
# 2024-11-12 19:22:25,752 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000008_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,753 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000008_0
# 2024-11-12 19:22:25,753 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 5, commitMemory -> 8, usedMemory ->10
# 2024-11-12 19:22:25,755 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000001_0 decomp: 20 len: 24 to MEMORY
# 2024-11-12 19:22:25,756 INFO reduce.InMemoryMapOutput: Read 20 bytes from map-output for attempt_local928394036_0001_m_000001_0
# 2024-11-12 19:22:25,756 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 20, inMemoryMapOutputs.size() -> 6, commitMemory -> 10, usedMemory ->30
# 2024-11-12 19:22:25,759 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000007_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,760 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000007_0
# 2024-11-12 19:22:25,760 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 7, commitMemory -> 30, usedMemory ->32
# 2024-11-12 19:22:25,762 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000004_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,763 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000004_0
# 2024-11-12 19:22:25,763 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 8, commitMemory -> 32, usedMemory ->34
# 2024-11-12 19:22:25,765 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000003_0 decomp: 2 len: 6 to MEMORY
# 2024-11-12 19:22:25,766 INFO reduce.InMemoryMapOutput: Read 2 bytes from map-output for attempt_local928394036_0001_m_000003_0
# 2024-11-12 19:22:25,766 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2, inMemoryMapOutputs.size() -> 9, commitMemory -> 34, usedMemory ->36
# 2024-11-12 19:22:25,768 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local928394036_0001_m_000000_0 decomp: 21 len: 25 to MEMORY
# 2024-11-12 19:22:25,768 INFO reduce.InMemoryMapOutput: Read 21 bytes from map-output for attempt_local928394036_0001_m_000000_0
# 2024-11-12 19:22:25,769 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 21, inMemoryMapOutputs.size() -> 10, commitMemory -> 36, usedMemory ->57
# 2024-11-12 19:22:25,769 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2024-11-12 19:22:25,771 INFO mapred.LocalJobRunner: 10 / 10 copied.
# 2024-11-12 19:22:25,771 INFO reduce.MergeManagerImpl: finalMerge called with 10 in-memory map-outputs and 0 on-disk map-outputs
# 2024-11-12 19:22:25,779 INFO mapred.Merger: Merging 10 sorted segments
# 2024-11-12 19:22:25,780 INFO mapred.Merger: Down to the last merge-pass, with 2 segments left of total size: 20 bytes
# 2024-11-12 19:22:25,781 INFO reduce.MergeManagerImpl: Merged 10 segments, 57 bytes to disk to satisfy reduce memory limit
# 2024-11-12 19:22:25,782 INFO reduce.MergeManagerImpl: Merging 1 files, 43 bytes from disk
# 2024-11-12 19:22:25,783 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2024-11-12 19:22:25,783 INFO mapred.Merger: Merging 1 sorted segments
# 2024-11-12 19:22:25,783 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 29 bytes
# 2024-11-12 19:22:25,784 INFO mapred.LocalJobRunner: 10 / 10 copied.
# 2024-11-12 19:22:25,813 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2024-11-12 19:22:25,815 INFO mapred.Task: Task:attempt_local928394036_0001_r_000000_0 is done. And is in the process of committing
# 2024-11-12 19:22:25,816 INFO mapred.LocalJobRunner: 10 / 10 copied.
# 2024-11-12 19:22:25,816 INFO mapred.Task: Task attempt_local928394036_0001_r_000000_0 is allowed to commit now
# 2024-11-12 19:22:25,818 INFO output.FileOutputCommitter: Saved output of task 'attempt_local928394036_0001_r_000000_0' to file:/content/grep-temp-1908159858
# 2024-11-12 19:22:25,819 INFO mapred.LocalJobRunner: reduce > reduce
# 2024-11-12 19:22:25,820 INFO mapred.Task: Task 'attempt_local928394036_0001_r_000000_0' done.
# 2024-11-12 19:22:25,824 INFO mapred.Task: Final Counters for attempt_local928394036_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=321853
# 		FILE: Number of bytes written=995365
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=97
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=2
# 		Shuffled Maps =10
# 		Failed Shuffles=0
# 		Merged Map outputs=10
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=485490688
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=147
# 2024-11-12 19:22:25,825 INFO mapred.LocalJobRunner: Finishing task: attempt_local928394036_0001_r_000000_0
# 2024-11-12 19:22:25,826 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2024-11-12 19:22:26,143 INFO mapreduce.Job:  map 100% reduce 100%
# 2024-11-12 19:22:26,144 INFO mapreduce.Job: Job job_local928394036_0001 completed successfully
# 2024-11-12 19:22:26,176 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=3461086
# 		FILE: Number of bytes written=10945387
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=842
# 		Map output records=28
# 		Map output bytes=475
# 		Map output materialized bytes=97
# 		Input split bytes=969
# 		Combine input records=28
# 		Combine output records=2
# 		Reduce input groups=2
# 		Reduce shuffle bytes=97
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=4
# 		Shuffled Maps =10
# 		Failed Shuffles=0
# 		Merged Map outputs=10
# 		GC time elapsed (ms)=49
# 		Total committed heap usage (bytes)=4956618752
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=31720
# 	File Output Format Counters
# 		Bytes Written=147
# 2024-11-12 19:22:26,229 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-11-12 19:22:26,242 INFO input.FileInputFormat: Total input files to process : 1
# 2024-11-12 19:22:26,245 INFO mapreduce.JobSubmitter: number of splits:1
# 2024-11-12 19:22:26,312 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1331019216_0002
# 2024-11-12 19:22:26,312 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-11-12 19:22:26,497 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2024-11-12 19:22:26,497 INFO mapreduce.Job: Running job: job_local1331019216_0002
# 2024-11-12 19:22:26,498 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2024-11-12 19:22:26,498 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:26,498 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:26,498 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:26,499 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2024-11-12 19:22:26,503 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2024-11-12 19:22:26,503 INFO mapred.LocalJobRunner: Starting task: attempt_local1331019216_0002_m_000000_0
# 2024-11-12 19:22:26,504 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:26,504 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:26,504 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:26,505 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:26,507 INFO mapred.MapTask: Processing split: file:/content/grep-temp-1908159858/part-r-00000:0+135
# 2024-11-12 19:22:26,533 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-11-12 19:22:26,533 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-11-12 19:22:26,534 INFO mapred.MapTask: soft limit at 83886080
# 2024-11-12 19:22:26,534 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-11-12 19:22:26,534 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-11-12 19:22:26,535 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-11-12 19:22:26,545 INFO mapred.LocalJobRunner:
# 2024-11-12 19:22:26,557 INFO mapred.MapTask: Starting flush of map output
# 2024-11-12 19:22:26,557 INFO mapred.MapTask: Spilling map output
# 2024-11-12 19:22:26,557 INFO mapred.MapTask: bufstart = 0; bufend = 33; bufvoid = 104857600
# 2024-11-12 19:22:26,557 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214392(104857568); length = 5/6553600
# 2024-11-12 19:22:26,559 INFO mapred.MapTask: Finished spill 0
# 2024-11-12 19:22:26,562 INFO mapred.Task: Task:attempt_local1331019216_0002_m_000000_0 is done. And is in the process of committing
# 2024-11-12 19:22:26,564 INFO mapred.LocalJobRunner: map
# 2024-11-12 19:22:26,564 INFO mapred.Task: Task 'attempt_local1331019216_0002_m_000000_0' done.
# 2024-11-12 19:22:26,564 INFO mapred.Task: Final Counters for attempt_local1331019216_0002_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=603781
# 		FILE: Number of bytes written=1991329
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2
# 		Map output records=2
# 		Map output bytes=33
# 		Map output materialized bytes=43
# 		Input split bytes=112
# 		Combine input records=0
# 		Spilled Records=2
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=485490688
# 	File Input Format Counters
# 		Bytes Read=147
# 2024-11-12 19:22:26,565 INFO mapred.LocalJobRunner: Finishing task: attempt_local1331019216_0002_m_000000_0
# 2024-11-12 19:22:26,565 INFO mapred.LocalJobRunner: map task executor complete.
# 2024-11-12 19:22:26,569 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2024-11-12 19:22:26,585 INFO mapred.LocalJobRunner: Starting task: attempt_local1331019216_0002_r_000000_0
# 2024-11-12 19:22:26,602 INFO output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2024-11-12 19:22:26,603 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-11-12 19:22:26,603 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-11-12 19:22:26,603 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-11-12 19:22:26,603 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@61d05eb8
# 2024-11-12 19:22:26,606 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-11-12 19:22:26,614 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2024-11-12 19:22:26,618 INFO reduce.EventFetcher: attempt_local1331019216_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2024-11-12 19:22:26,621 INFO reduce.LocalFetcher: localfetcher#2 about to shuffle output of map attempt_local1331019216_0002_m_000000_0 decomp: 39 len: 43 to MEMORY
# 2024-11-12 19:22:26,622 INFO reduce.InMemoryMapOutput: Read 39 bytes from map-output for attempt_local1331019216_0002_m_000000_0
# 2024-11-12 19:22:26,622 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 39, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->39
# 2024-11-12 19:22:26,623 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2024-11-12 19:22:26,624 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-11-12 19:22:26,624 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2024-11-12 19:22:26,625 INFO mapred.Merger: Merging 1 sorted segments
# 2024-11-12 19:22:26,626 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 29 bytes
# 2024-11-12 19:22:26,627 INFO reduce.MergeManagerImpl: Merged 1 segments, 39 bytes to disk to satisfy reduce memory limit
# 2024-11-12 19:22:26,627 INFO reduce.MergeManagerImpl: Merging 1 files, 43 bytes from disk
# 2024-11-12 19:22:26,627 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2024-11-12 19:22:26,627 INFO mapred.Merger: Merging 1 sorted segments
# 2024-11-12 19:22:26,627 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 29 bytes
# 2024-11-12 19:22:26,628 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-11-12 19:22:26,632 INFO mapred.Task: Task:attempt_local1331019216_0002_r_000000_0 is done. And is in the process of committing
# 2024-11-12 19:22:26,636 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-11-12 19:22:26,636 INFO mapred.Task: Task attempt_local1331019216_0002_r_000000_0 is allowed to commit now
# 2024-11-12 19:22:26,637 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1331019216_0002_r_000000_0' to file:/root/grep_example
# 2024-11-12 19:22:26,641 INFO mapred.LocalJobRunner: reduce > reduce
# 2024-11-12 19:22:26,641 INFO mapred.Task: Task 'attempt_local1331019216_0002_r_000000_0' done.
# 2024-11-12 19:22:26,641 INFO mapred.Task: Final Counters for attempt_local1331019216_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=603899
# 		FILE: Number of bytes written=1991406
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=43
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=2
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=485490688
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=34
# 2024-11-12 19:22:26,641 INFO mapred.LocalJobRunner: Finishing task: attempt_local1331019216_0002_r_000000_0
# 2024-11-12 19:22:26,641 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2024-11-12 19:22:27,498 INFO mapreduce.Job: Job job_local1331019216_0002 running in uber mode : false
# 2024-11-12 19:22:27,499 INFO mapreduce.Job:  map 100% reduce 100%
# 2024-11-12 19:22:27,499 INFO mapreduce.Job: Job job_local1331019216_0002 completed successfully
# 2024-11-12 19:22:27,502 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=1207680
# 		FILE: Number of bytes written=3982735
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2
# 		Map output records=2
# 		Map output bytes=33
# 		Map output materialized bytes=43
# 		Input split bytes=112
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=43
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=4
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=970981376
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=147
# 	File Output Format Counters
# 		Bytes Written=34

# %%
# !cat ~/grep_example/*
# Out:
# 27	allowed.
# 1	allowed

# %% [markdown]
# # HDFS

# %% [markdown]
# Las siguientes sentencias únicamente sirven para probar comandos básicos de HDFS no para gestionar una Infraestructura que en Google Colab no existe, en este caso el sistema de archivos HDFS es el mismo que el local

# %% [markdown]
# * Crear el directorio *prueba*

# %%
# !hdfs dfs -mkdir prueba

# %% [markdown]
# - Crear un fichero local :

# %%
# %%bash
# echo "Ejemplo de HDFS" > user.txt
# echo `date` >> user.txt
# cat user.txt
# Out:
# Ejemplo de HDFS
# Tue Nov 12 07:32:23 PM UTC 2024

# %%
# !hdfs dfs -put user.txt prueba/
# !hdfs dfs -ls prueba
# Out:
# Found 1 items
# -rw-r--r--   1 root root         48 2024-11-12 19:32 prueba/user.txt

# %% [markdown]
# - Mostrar su contenido

# %%
# !hdfs dfs -cat prueba/user.txt
# Out:
# Ejemplo de HDFS
# Tue Nov 12 07:32:23 PM UTC 2024

# %%
# %%bash
# hdfs dfs -tail prueba/user.txt
# Out:
# Ejemplo de HDFS
# Tue Nov 12 07:32:23 PM UTC 2024
